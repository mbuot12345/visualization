# %% [markdown]
# ### This is Python Revision

# %%
# This is a comment line and would not print
print ("This is the Data Analytics Track")
print('Tis one uses single quotation')
# Out:
# This is the Data Analytics Track
# Tis one uses single quotation

# %%
# performing calculations in jupyter
a = 56
b = 678
c = 5987
add = a+b+c # we are adding here
mul = b*c # we are multiplying here
div = (a*b)/c # we are dividing here
print(add)
print(mul)
print(div)
# Out:
# 6721
# 4059186
# 6.341740437614832

# %%
x = 15
y = 20
z = 10
result = x+y+z
anotherresult = str(result)
print('The sum of the numbers are'+ anotherresult)
# Out:
# The sum of the numbers are45

# %%
var1 = 50
var2 = 100
var3 = 200
sum = var1+var2+var3
prod = var1*var2
div = var1+var2/var3
print(sum)
print(prod)
print(div)
# Out:
# 350
# 5000
# 50.5

# %%
value1 = 300
value2 = 900
value3 = 1200
result = value3>value2
anotherresult = value3/value1
print(result)
print(anotherresult)
# Out:
# True
# 4.0

# %%
one = int(input('Number' ))
two = int(input('Number'))
three = int(input('Nunber'))
if(one>two and two>three)
        print(one)
elif(two>one>three)
        print(two)
else:
        print(three)
# Out:
#   File "<ipython-input-6-5d7aaf199a87>", line 4
#     if(one>two and two>three)
#                              ^
# SyntaxError: invalid syntax

# %%
# comparing values in two variables
value1 = 67
value2 = 12
result = value1 < value2
print(result)

# %%
print("beginning of program")
print("enter your salary") 
salary=int(input())
print("enter years of services")
services=int(input())
if (services>5):
    print("your bonus is",5 *salary)
else:
    print("no bonus")
print("end of program")

# %% [markdown]
#  ###You are in an aunction , where a car is to be sold. The bid agreed minimum bid for the car is # 500000. Write a program that considers four bids and declares the highest bid and announces that the car is sold to the highest bidder

# %%
#print("The program begins")

print("The name of the car is")
car= (input())
print("number of bid")
bid=int(input())
if (bid>=5000000):
    print ("you are the one with the highest bib" ,"car")
elif(bid>=400000):
    print("your the second rouner up")
elif(bid>=300000):
    print("your the second rouner up")
elif(bid>=50000):
    print("your the second rouner up")
else:
    print("your welcome to try again")

# %%
print("The auction begins")
bid1 = int (input("My offer is :"))
bid2 = int (input("My offer is :"))
bid3 = int(input("My offer is :"))
bid4 = int(input("My offer is :"))
if(bid1<500000):
    print("upgrade your bid")
elif(bid2<500000):
    print("You need to upgrade more")
elif(bid3<500000):
    print("more chance to upgrade")
else:
    print("you have won")

# %%
mybirds = ["parrot","sparrow","crow","eagle"]
mybirds.insert(1,'crow')
mybirds

# %%
 # dataText = read("names_ages.txt","r")
# dataText
myFile = open("names_ages.txt","r")
print(myFile.read())

# %%
import pandas as pd
import numpy as np

# %%
Abujabranch = pd.read_csv(r"C:\Users\Mbuotidem urom\Documents\DATASETS\Abuja_Branch.csv")
Abujabranch
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1    351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2    529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3    299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4    319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# ..           ...    ...    ...           ...     ...                     ...
# 327  552-44-5977      B  Abuja        Member    Male       Health and beauty
# 328  430-53-4718      B  Abuja        Member    Male       Health and beauty
# 329  602-16-6955      B  Abuja        Normal  Female       Sports and travel
# 330  690-01-6631      B  Abuja        Normal    Male     Fashion accessories
# 331  303-96-2227      B  Abuja        Normal  Female      Home and lifestyle
#
# ...

# %%
Abujabranch.rename(columns = {'City':'Town'},inplace=True)
Abujabranch.head()
# Out:
#     Invoice ID Branch   Town Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
Lagosbranch = pd.read_csv(r"C:\Users\Mbuotidem urom\Documents\DATASETS\Lagos_Branch.csv")
Lagosbranch
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Lagos        Member  Female       Health and beauty
# 1    631-41-3108      A  Lagos        Normal    Male      Home and lifestyle
# 2    123-19-1176      A  Lagos        Member    Male       Health and beauty
# 3    373-73-7910      A  Lagos        Normal    Male       Sports and travel
# 4    355-53-5943      A  Lagos        Member  Female  Electronic accessories
# ..           ...    ...    ...           ...     ...                     ...
# 335  886-18-2897      A  Lagos        Normal  Female      Food and beverages
# 336  745-74-0715      A  Lagos        Normal    Male  Electronic accessories
# 337  727-02-1313      A  Lagos        Member    Male      Food and beverages
# 338  347-56-2442      A  Lagos        Normal    Male      Home and lifestyle
# 339  849-09-3807      A  Lagos        Member  Female     Fashion accessories
#
# ...

# %%
Portharcourtbranch = pd.read_csv(r"C:\Users\Mbuotidem urom\Documents\DATASETS\Port_Harcourt_Branch.csv")
Portharcourtbranch
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    226-31-3081      C  Port Harcourt        Normal  Female
# 1    699-14-3026      C  Port Harcourt        Normal    Male
# 2    315-22-5665      C  Port Harcourt        Normal  Female
# 3    300-71-4605      C  Port Harcourt        Member    Male
# 4    183-56-6882      C  Port Harcourt        Member  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0    Electronic accessories      5500.8         5   1375.20   28879.20
# 1    Electronic accessories     30740.4         7  10759.14  225941.94
# ...

# %%
Food_Bev = Abujabranch[Abujabranch["Product line"]=="Food and beverages"]
Food_Bev.head(10)
# Out:
#      Invoice ID Branch   Town Customer type  Gender        Product line  \
# 0   692-92-5582      B  Abuja        Member  Female  Food and beverages
# 8   145-94-9061      B  Abuja        Normal  Female  Food and beverages
# 17  727-46-3608      B  Abuja        Member  Female  Food and beverages
# 24  510-95-6347      B  Abuja        Member  Female  Food and beverages
# 25  847-38-7188      B  Abuja        Normal  Female  Food and beverages
# 49  548-46-9322      B  Abuja        Normal    Male  Food and beverages
# 51  316-55-4634      B  Abuja        Member    Male  Food and beverages
# 53  414-12-7047      B  Abuja        Normal    Male  Food and beverages
# 54  895-66-0685      B  Abuja        Member    Male  Food and beverages
# 70  790-29-1172      B  Abuja        Normal  Female  Food and beverages
#
#     Unit price  Quantity   Tax 5%      Total       Date   Time Payment  \
# 0      19742.4         3  2961.36   62188.56  2/20/2019  13:27    Card
# ...

# %%
high_Buyers = Abujabranch[Abujabranch]

# %%
exFile = pd.ExcelFile("Bookshop.xlsx")
books = exFile.parse('Book')

books
# Out:
#    BookID                                              Title AuthID
# 0   BB194                                      Ballinby Boys  AM329
# 1   NC652                                 Nothing But Capers  AS443
# 2   AD222                               Alanna Saves the Day  BH149
# 3   PA169                                         Post Alley  BM856
# 4   TC188                                 Thatchwork Cottage  BM856
# 5   ZT703                                   Zero over Twelve  BM856
# 6   PP866                                        Portmeirion  BT132
# 7   RR774                                           Rystwyth  BT132
# 8   TM925                                  The Mallemaroking  BT132
# 9   CH391                                   Can I Be Honest?  CF829
# 10  NL209                                  No More Lightning  CF829
# 11  NR695                          9803 North Millworks Road  CS190
# 12  TH296                The Winchcombe Railway Museum Heist  CS190
# ...

# %%
import matplotlib.pyplot as plt
# let us define some data points
time = (1.00,1.23,2.30,3.50.4.45,5.22,6.0)
# let us define the amount someone makes per this times
moneyMade = (20,35,102,220,320,500)
# plotting the wave
plt.plot(time,moneyMade)
# Out:
#   File "<ipython-input-28-beac03f6628e>", line 3
#     time = (1.00,1.23,2.30,3.50.4.45,5.22,6.0)
#                                ^
# SyntaxError: invalid syntax

# %%
books.describe()
# Out:
#        BookID                 Title AuthID
# count      58                    58     58
# unique     58                    58     34
# top     NL209  Interrobangs for All  LD375
# freq        1                     1      8
